# %%
import os
import torch
from IPython.display import Image, clear_output  # to display images

# Clone YOLOv5 repository
os.system("git clone https://github.com/ultralytics/yolov5")  # clone the repo
os.chdir('yolov5')  # change directory to yolov5

# Install dependencies
os.system("pip install -r requirements.txt")  # install dependencies
os.system("pip install roboflow")  # install roboflow

# Check if torch is installed correctly and if CUDA is available
print(f"Setup complete. Using torch {torch.__version__} ({torch.cuda.get_device_properties(0).name if torch.cuda.is_available() else 'CPU'})")

# %%
# set up environment
os.environ["DATASET_DIRECTORY"] = "/content/datasets"

# %%
# Ensure we're in the right directory to download our custom dataset
import os
os.makedirs("../datasets/", exist_ok=True)
# %cd ../datasets/
# Out:
# d:\Programming\Thesis Data\Classification Test 1\datasets

# %%
# %pip install roboflow==1.1.48 -q

from roboflow import Roboflow
rf = Roboflow(api_key="wFLSPC46dkyKk2ajWVGt")
project = rf.workspace("bamboo-v2").project("growthhabitclassification")
version = project.version(2)
dataset = version.download("folder")
# Out:
# [notice] A new release of pip available: 22.3 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# loading Roboflow workspace...
# loading Roboflow project...

# %%
#Save the dataset name to the environment so we can use it in a system call later
dataset_name = dataset.location.split(os.sep)[-1]
os.environ["DATASET_NAME"] = dataset_name

# %%
#Download a Pre-trained model for optimization and faster training
# %cd ../yolov5
from utils.downloads import attempt_download

p5 = ['n', 's', 'm', 'l', 'x']  # P5 models
cls = [f'{x}-cls' for x in p5]  # classification models

for x in cls:
    attempt_download(f'weights/yolov5{x}.pt')
# Out:
# d:\Programming\Thesis Data\Classification Test 1\yolov5

# %%
# %cd ../yolov5
# !python classify/train.py --model yolov5s-cls.pt --data "D:/Programming/Thesis Data/Classification Test 1/datasets/BambooImages" --epochs 200 --img 224 --batch-size 8 --pretrained "weights/yolov5s-cls.pt"
# Out:
# d:\Programming\Thesis Data\Classification Test 1\yolov5
# Error decoding JSON from C:\Users\ACER\AppData\Roaming\Ultralytics\settings.json. Starting with an empty dictionary.
# Error decoding JSON from C:\Users\ACER\AppData\Roaming\Ultralytics\settings.json. Starting with an empty dictionary.
# Error decoding JSON from C:\Users\ACER\AppData\Roaming\Ultralytics\settings.json. Starting with an empty dictionary.
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\ACER\AppData\Roaming\Ultralytics\settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at 'C:\Users\ACER\AppData\Roaming\Ultralytics\settings.json'
# ...

# %%
# !python classify/val.py --weights "D:\Programming\Thesis Data\Classification Test 1\yolov5\runs\train-cls\exp4\weights\best.pt" --data "D:/Programming/Thesis Data/Classification Test 1/datasets/BambooImages"
# Out:
# classify\val: data=D:/Programming/Thesis Data/Classification Test 1/datasets/BambooImages, weights=['D:\\Programming\\Thesis Data\\Classification Test 1\\yolov5\\runs\\train-cls\\exp4\\weights\\best.pt'], batch_size=128, imgsz=224, device=, workers=8, verbose=True, project=runs\val-cls, name=exp, exist_ok=False, half=False, dnn=False
# fatal: cannot change to 'D:\Programming\Thesis': No such file or directory
# YOLOv5  2025-1-31 Python-3.11.0 torch-2.6.0+cu118 CUDA:0 (NVIDIA GeForce MX250, 2048MiB)
#
# Fusing layers...
# Model summary: 117 layers, 4169250 parameters, 0 gradients, 10.4 GFLOPs
#
# testing:   0%|          | 0/1 [00:00<?, ?it/s]d:\Programming\Thesis Data\Classification Test 1\yolov5\classify\val.py:111: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=device.type != "cpu"):
#
# ...
# testing: 100%|██████████| 1/1 [00:12<00:00, 12.97s/it]
# ...

# %%
# %pip install torch torchvision tkinter pillow
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement tkinter (from versions: none)
# ERROR: No matching distribution found for tkinter
#
# [notice] A new release of pip available: 22.3 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
